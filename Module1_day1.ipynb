# %%
5+4
# Out:
# 9

# %% [markdown]
# **Data types in python**

# %%
1,2,-3,3.456 #numeric data type

"Hello my name is micah" #string data types

True #boolean
False #boolean

21:00:00 #dateandtime

# %% [markdown]
# ###*INTEGERS AND FLOATS*

# %% [markdown]
# ###**ARITHEMATIC OPERATIONS **

# %%
#Substraction
5-4
# Out:
# 1

# %%
#ADDITION
3+2
# Out:
# 5

# %%
#DIVISION
print(7/2)
print(7//2)#floor division //
print(-7/2)
print(-7//2)
# Out:
# 3.5
# 3
# -3.5
# -4

# %%
#Multiplication
3*4
# Out:
# 12

# %%
#Exponetiation
2**3
# Out:
# 8

# %%
#MODULUS--REMAINDER AFTER DIVISION
5%2
# Out:
# 1

# %%
#Order of operations in python
2+10*3-7
# Out:
# 25

# %%
((2+(10*3))-7)
# Out:
# 25

# %%
#SCIENTIFIC REPRESENTATION OF NUMBERS
4E5
# Out:
# 400000.0

# %% [markdown]
# **WHAT ARE VARIABLES? :- AN ENTITY USED TO STORE INFORMATION AND RETRIEVE LATER**

# %%
x=5
print(x)
# Out:
# 5

# %%
x=5
y=4
z=x+y
print(z)
# Out:
# 9

# %% [markdown]
# id-->memory location of the variable stored in computer

# %%
print(hex(id(z)))
# Out:
# 0x55c15abe1b00

# %%
#Find out the data type of variable
type(z)
# Out:
# int

# %%
x=5
y=9.8
z=x//y
print(z)
# Out:
# 0.0

# %%
avagadaro=6.22e23
print(avagadaro)
# Out:
# 6.22e+23

# %% [markdown]
# **BOOLEAN**

# %%
5<6
# Out:
# True

# %%
2==2.0
# Out:
# True

# %%
9//4
# Out:
# 2

# %%
4%3+3
# Out:
# 4
