# %% [markdown]
# # Gradient Descent for Optimization

# %%
# Matrix computations
from numpy import *

# Plotting
from matplotlib.pyplot import *

# Change size of figures
fig_size = [9,7]
rcParams["figure.figsize"] = fig_size

# %% [markdown]
# ## Minimizing multiple variable function
#
# Let us consider the following straight forward bivariate function $$f(x,y) = x^2 + y^2 + 1.$$ Since this a function of two variables, we have have the following partial derivatives $$\frac{df(x)}{dx} = f_{x} = 2x \text{ and } \frac{df(y)}{dy} = f_{y} = 2y.$$ Note that its easy to argue that the global minimum of $f(x,y)$ is (0,0) since $f(0,0) = 1$ and $f(x,y) \ge 1.$

# %%
# Plotting in 3D
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

# f(x,y) = x^2 + y^2 + 1
def f(x,y):
    return x**2 + y**2 + 1

# (X,Y) grid on [-5,5]

x = arange(-5, 5, 0.25)
y = arange(-5, 5, 0.25)
X, Y = meshgrid(x, y)


# z = x^2 + y^2
Z = f(X,Y)

# Plot (X,Y) in 3D
fig = figure(1)
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.RdBu,linewidth=0, antialiased=False)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
fig.colorbar(surf, shrink = 0.7, aspect=5)
show()

# %% [markdown]
# ### Finding global minimum using gradient descent
#
# For this example the gradient descent algorithm is simplified to
#
# $$
# \begin{bmatrix}
#     x^{t+1} \\
#     y^{t+1}
# \end{bmatrix}
# =
# \begin{bmatrix}
#     x^{t} \\
#     y^{t}
# \end{bmatrix}
# -
# \lambda
# \begin{bmatrix}
#     2x^{t} \\
#     2y^{t} \\
# \end{bmatrix},
# $$
#
# where $t$ is the gradient descent iteration.

# %%
def plotf(x, x_dots)
# Out:
#   File "<ipython-input-31-86f273b9b7b3>", line 1
#     def plotf(x, x_dots)
#                         ^
# SyntaxError: invalid syntax

# %%
# Your code here

def part_deri(x):
  return 2*x 

def part_deriv(y):
  return 2*y

def gradient_descent(part_deri,part_deriv,x_prev,y_prev,learning_rate):
  e=0.001
  grad_i=1
  x_next=x_prev-learning_rate*part_deri(x_prev)
  y_next=y_prev-learning_rate*part_deriv(y_prev)
  sequence=np.array([])
  sequence=np.append(sequence,x_next)
  sequence1=np.array([])
  sequence1=np.append(sequence1,y_next)



  while np.sqrt((x_next-x_prev)**2 + (y_next-y_prev)**2) > e:
    x_prev=x_next
    x_next=x_prev-learning_rate*part_deri(x_prev)
    sequence=np.append(sequence,x_next)
    y_prev=y_next
    y_next=y_prev-learning_rate*part_deriv(y_prev)
    sequence1=np.append(sequence1,y_next)
    grad_i=grad_i+1
  return x_next,y_next,sequence,sequence1,grad_i

# %%
def plotf(x,y,xdots,ydots,label):

  # Change size of figures
  fig_size = [15,12]
  rcParams["figure.figsize"] = fig_size
    
  X, Y = meshgrid(x, y)


  # z = x^2 + y^2
  Z = f(X,Y)

  # Plot (X,Y) in 3D
  fig = figure(1)
  ax = fig.gca(projection='3d')
  surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.RdBu,linewidth=0, antialiased=False)

  #finding z for x_dot and y_dot
  z=f(x_dot,y_dot)

  #Plotting convergence points.
  ax.plot3D(x_dot,y_dot,z,c='g',marker='o',markerfacecolor='blue',markersize=6)
  plt.title(label)

  ax.zaxis.set_major_locator(LinearLocator(10))
  ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
  fig.colorbar(surf, shrink = 0.7, aspect=5)
  show()

# %%
grad_output = gradient_descent(part_deri, part_deriv,5,5,0.2)
x_dot=grad_output[2]
y_dot=grad_output[3]
xy=list(zip(x_dot,y_dot))
print('global minima point = '+'{:.2f}'.format(grad_output[0]) + ',{:.2f}'.format(grad_output[1]))
print('x,y coordinates')
xy
# Out:
# global minima point = 0.00,0.00
# x,y coordinates
# [(3.0, 3.0),
#  (1.7999999999999998, 1.7999999999999998),
#  (1.0799999999999998, 1.0799999999999998),
#  (0.6479999999999999, 0.6479999999999999),
#  (0.3887999999999999, 0.3887999999999999),
#  (0.23327999999999993, 0.23327999999999993),
#  (0.13996799999999995, 0.13996799999999995),
#  (0.08398079999999997, 0.08398079999999997),
#  (0.05038847999999998, 0.05038847999999998),
#  (0.030233087999999984, 0.030233087999999984),
#  (0.018139852799999988, 0.018139852799999988),
#  (0.010883911679999993, 0.010883911679999993),
#  (0.006530347007999996, 0.006530347007999996),
#  (0.0039182082047999976, 0.0039182082047999976),
#  (0.0023509249228799984, 0.0023509249228799984),
#  (0.001410554953727999, 0.001410554953727999),
#  (0.0008463329722367994, 0.0008463329722367994)]

# %%
x = arange(-5, 5, 0.25)
y = arange(-5, 5, 0.25)

plotf(x,y,x_dot,y_dot,"Gradient Descent with alpha =0.2 and start point = 5,5")
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-32-55807ad4ca54> in <module>()
#       2 y = arange(-5, 5, 0.25)
#       3
# ----> 4 plotf(x,y,x_dot,y_dot,"Gradient Descent with alpha =0.2 and start point = 5,5")
#
# <ipython-input-25-feff03f0e585> in plotf(x, y, xdots, ydots, label)
#      21   #Plotting convergence points.
#      22   ax.plot3D(x_dot,y_dot,z,c='g',marker='o',markerfacecolor='blue',markersize=6)
# ---> 23   plt.title(label)
#      24
#      25   ax.zaxis.set_major_locator(LinearLocator(10))
#
# NameError: global name 'plt' is not defined
